# %%
a=10
b=20
print (a+b)
# Out:
# 30

# %%
x=50
y="KLH-BACHUPALLY"
z=5.5
print(x,y,z)

a,b,c="orange","banana","cherry"
print(a,b,c)

a=b=c="orange"
print(a)

# print statement with seperator
print("Hello","How are you",sep="!!")
print("Hello","How are you","good",sep="**")
# Out:
# 50 KLH-BACHUPALLY 5.5
# orange banana cherry
# orange
# Hello!!How are you
# Hello**How are you**good

# %%
# if else
a=input("enter value of a ")
print(a)

a=int(input())
b=10
print(a+b)

a=int(input())
b=int(input())
if a>b:
  print(a)
else:
  print(b)

a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
  print(a)
elif b>a and b>c:
  print(b)
else:
  print(c)
# Out:
# 30
# 20
# 10
# 30

# %%
#use of type method
x=10
b=5.5
c=-35.59
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# type casting
a=int(1)
b=float(1)
c=str(1)
d=int(b)
print(a)
print(b)
print(c)
print(d)

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 1
# 1.0
# 1
# 1
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
# slicing strings [starting : ending]
b="KLH BACHUPALLY"
print(b[2:5])
print(b[10:])
print(b[:6])
print(b[:-5])
print(b[-5:])
# Out:
# H B
# ALLY
# KLH BA
# KLH BACHU
# PALLY

# %%
# string handling functions
a="KL UNIVERSITY"
print(a.lower())
print(a.find("L"))
print(a.capitalize())
print(a.swapcase())
print(a.title())
print(len(a))

# concatenation
a="KLH"
b="BACHUPALLY"
c=a+b
print(c)
c=a+" "+b
print(c)
# Out:
# kl university
# 1
# Kl university
# kl university
# Kl University
# 13
# KLHBACHUPALLY
# KLH BACHUPALLY

# %%
# while
i=1
while i<6:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
