# %%
import pandas as pd
data={ 'apples':[3,2,0,1],'oranges':[0,3,7,2]}
df=pd.DataFrame(data)
df.to_csv('new_dataset.csv')
df.to_csv('new_data.json')

print(df)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
import pandas as pd
data={ 'id':[1,2,3,4,5],'name':['a','b','c','d','e'],'branch':['cse','ece','cse','ece','cse'],'section':[1,2,3,4,5]}
df=pd.DataFrame(data,index=[101,102,103,104,105])
df
df.loc[103]
# Out:
# id           3
# name         c
# branch     cse
# section      3
# Name: 103, dtype: object

# %%
import pandas as pd
df=pd.read_csv('tips.csv',index_col=0)
df
# Out:
#              tip     sex smoker   day    time  size  price_per_person  \
# total_bill
# 16.99       1.01  Female     No   Sun  Dinner     2              8.49
# 10.34       1.66    Male     No   Sun  Dinner     3              3.45
# 21.01       3.50    Male     No   Sun  Dinner     3              7.00
# 23.68       3.31    Male     No   Sun  Dinner     2             11.84
# 24.59       3.61  Female     No   Sun  Dinner     4              6.15
# ...          ...     ...    ...   ...     ...   ...               ...
# 29.03       5.92    Male     No   Sat  Dinner     3              9.68
# 27.18       2.00  Female    Yes   Sat  Dinner     2             13.59
# 22.67       2.00    Male    Yes   Sat  Dinner     2             11.34
# 17.82       1.75    Male     No   Sat  Dinner     2              8.91
# 18.78       3.00  Female     No  Thur  Dinner     2              9.39
#
#                     Payer Name         CC Number Payment ID
# total_bill
# ...

# %%
import pandas as pd
df=pd.read_csv('movies.csv')
# movies_df=pd.read_csv("movies.csv",index_col="title")
# movies_df.head()
# movies_df.tail()
# movies_df.head(10)
# movies_df.tail(2)
# movies_df
df
# movies_df.info()
# movies_df.shape
# movies_df.describe()
# movies_df=movies_df.drop_duplicates()

# x=pd.concat([movies_df,movies_df])
# x.shape
# x=x.drop_duplicates()
# x.shape
# movies_df=movies_df.drop_duplicates(inplace=True)
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
import pandas as pd
# one=[{'a':1,'b':2,'c':3}]
# two={['d':4,'e':5,'f':6]}
# df1=pd.DataFrame(one,index=['first','second','third'],columns=['a','b'])
# df2=pd.DataFrame(one,index=['first','second','third'],columns=['a','b1'])
# print(df1)
# print(df2)
# df1.to_csv('one.csv')

d={'one':pd.Series([1,2,3],index=['a','b','c']),'two':pd.Series([1,2,3,4],index=['a','b','c','d'])}
df=pd.DataFrame(d)
print("adding new col")
df['three']=pd.Series([10,20,30],index=['a','b','c'])
print(df)
print("deleting col")
del df['one']
print(df)
print(df[2:4])
# Out:
# adding new col
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN
# deleting col
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN
#    two  three
# c    3   30.0
# d    4    NaN

# %%
import pandas as pd
df=pd.read_csv('movies.csv')
total_nans=df.isna().sum().sum()
nans_per_column=df.isna().sum()
print("total nans:",total_nans)
print("nans per column:\n",nans_per_column)
df.dropna(axis=1)
df.fillna(0)
df.shape
# Out:
# total nans: 4454
# nans per column:
#  index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64
# (4803, 24)

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'age':[1,2,np.nan,4,5],'dept':['hr','finance','finance',np.nan,'it']})
print(df)
df['age'].fillna(df['age'].mean(),inplace=True)
# print(df)
df_ffill=df.copy()
df_ffill.fillna(method='ffill',inplace=True)
print(df_ffill)
df_bfill=df.copy()
df_bfill.fillna(method='bfill',inplace=True)
print(df_bfill)
# Out:
#    age     dept
# 0  1.0       hr
# 1  2.0  finance
# 2  NaN  finance
# 3  4.0      NaN
# 4  5.0       it
#    age     dept
# 0  1.0       hr
# 1  2.0  finance
# 2  3.0  finance
# 3  4.0  finance
# 4  5.0       it
#    age     dept
# 0  1.0       hr
# 1  2.0  finance
# 2  3.0  finance
# 3  4.0       it
# 4  5.0       it
# /tmp/ipykernel_884/686432235.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].mean(),inplace=True)
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    'Date': ['2025-01-05', '05/01/2025', 'Jan 5, 2025', '2025.01.05']
})

df['Date'] = pd.to_datetime(df['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(df)
# Out:
#          Date
# 0  2025-01-05
# 1         NaN
# 2         NaN
# 3         NaN

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'BOB', 'charlie', 'DAVID']
})

df['Name_lower'] = df['Name'].str.lower()
print(df)

df['Name_upper'] = df['Name'].str.upper()

print(df)
# Out:
#       Name Name_lower
# 0    Alice      alice
# 1      BOB        bob
# 2  charlie    charlie
# 3    DAVID      david
#       Name Name_lower Name_upper
# 0    Alice      alice      ALICE
# 1      BOB        bob        BOB
# 2  charlie    charlie    CHARLIE
# 3    DAVID      david      DAVID

# %%
movies_df=pd.read_csv("movies.csv",index_col="title")
movies_df['name_upper']=movies_df['original_title'].str.upper()
print(df)
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...
